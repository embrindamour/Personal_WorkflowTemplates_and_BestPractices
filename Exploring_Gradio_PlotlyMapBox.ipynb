# %%
import gradio as gr
import plotly.express as px
import pandas as pd

MAPBOX_TOKEN = "pk.eyJ1IjoiZW1tYW51ZWxsZWJyaW4iLCJhIjoiY21qYWtnYTljMDczaDNjcHk1b3RidGxsaiJ9.0faxbJ8wg99l5cc3uj69mA"
# Example geolocated data (what Mapper would output)
df = pd.DataFrame({
    "place": ["Kyiv", "Gaza", "Taipei", "Washington, DC"],
    "lat": [50.4501, 31.5017, 25.0330, 38.9072],
    "lon": [30.5234, 34.4668, 121.5654, -77.0369],
    "snippet": [
        "Discussed in context of military aid",
        "Mentioned during ceasefire negotiations",
        "Referenced in semiconductor geopolitics",
        "Cited in policy response coverage"
    ]
})

fig = px.scatter_mapbox(
    df,
    lat="lat",
    lon="lon",
    hover_name="place",
    hover_data={"snippet": True},
    zoom=1,
    height=500
)

fig.update_layout(
    mapbox_style="satellite-streets",
    mapbox_accesstoken=MAPBOX_TOKEN,
    mapbox_layers=[
        {
            "below": "traces",
            "sourcetype": "geojson",
            "source": {
                "type": "FeatureCollection",
                "features": [
                    {
                        "type": "Feature",
                        "geometry": {
                            "type": "Polygon",
                            "coordinates": [[
                                [-180, -85], [180, -85],
                                [180, 85], [-180, 85],
                                [-180, -85]
                            ]]
                        }
                    }
                ]
            },
            "type": "fill",
            "color": "rgba(255,255,255,0.35)"  # 👈 adjust opacity here
        }
    ],
    margin={"r":0,"t":0,"l":0,"b":0}
)

with gr.Blocks() as demo:
    gr.Markdown("## Basic Map Test")
    gr.Plot(fig)

demo.launch()
# Out:
# /var/folders/0w/pv3xqbrs43n3zvh2lb4x1nwc0000gn/T/ipykernel_55309/202743804.py:19: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
